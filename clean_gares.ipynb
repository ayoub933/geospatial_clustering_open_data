# %%
import os
import requests

# Créer le dossier "data" s’il n’existe pas
os.makedirs("data", exist_ok=True)

# URL du CSV open data
url = "https://ressources.data.sncf.com/explore/dataset/liste-des-gares/download/?format=csv&timezone=Europe/Paris&use_labels_for_header=true"

# Chemin de sortie
output_path = "data/liste-des-gares.csv"

# Télécharger et enregistrer
response = requests.get(url)
with open(output_path, 'wb') as f:
    f.write(response.content)

print("✅ Fichier téléchargé automatiquement dans 'data/liste-des-gares.csv'")
# Out:
# ✅ Fichier téléchargé automatiquement dans 'data/liste-des-gares.csv'

# %%
#Import des bibiliothèques
import pandas as pd

# %%
#Création du dataframe concernant le fichier csv liste-des-gares.csv
df=pd.read_csv("data/liste-des-gares.csv",sep=";")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[111], line 2
#       1 #Création du dataframe concernant le fichier csv liste-des-gares.csv
# ----> 2 df=pd.read_csv("liste-des-gares.csv",sep=";")
#
# ...

# %%
#Affichage des différentes caratéristiques et statistiques sur le dataframe
df.describe()
# Out:
#            CODE_UIC     CODE_LIGNE   RG_TRONCON      IDRESEAU         X_L93  \
# count  3.884000e+03    3884.000000  3884.000000  3.884000e+03  3.884000e+03
# mean   8.748032e+07  521884.659629     1.087539  2.743239e+04  6.956317e+05
# std    2.098847e+05  283574.601633     0.355320  4.316972e+05  1.966735e+05
# min    8.700148e+07    1000.000000     1.000000  0.000000e+00  1.471124e+05
# 25%    8.729517e+07  289000.000000     1.000000  4.047500e+03  5.746326e+05
# 50%    8.748433e+07  561000.000000     1.000000  5.423500e+03  6.779863e+05
# 75%    8.768335e+07  760000.000000     1.000000  6.734250e+03  8.483793e+05
# max    8.798872e+07  990331.000000     4.000000  1.033400e+07  1.079186e+06
#
#               Y_L93      X_WGS84      Y_WGS84
# count  3.884000e+03  3884.000000  3884.000000
# mean   6.690190e+06     2.942783    47.282230
# std    2.379177e+05     2.595450     2.143466
# min    6.147214e+06    -4.479243    42.419930
# 25%    6.511638e+06     1.388731    45.673065
# ...

# %%
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3884 entries, 0 to 3883
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CODE_UIC    3884 non-null   int64
#  1   LIBELLE     3884 non-null   object
#  2   FRET        3884 non-null   object
#  3   VOYAGEURS   3884 non-null   object
#  4   CODE_LIGNE  3884 non-null   int64
#  5   RG_TRONCON  3884 non-null   int64
#  6   PK          3884 non-null   object
#  7   COMMUNE     3884 non-null   object
#  8   DEPARTEMEN  3884 non-null   object
#  9   IDRESEAU    3884 non-null   int64
#  10  IDGAIA      3884 non-null   object
#  11  X_L93       3884 non-null   float64
#  12  Y_L93       3884 non-null   float64
#  13  X_WGS84     3884 non-null   float64
#  14  Y_WGS84     3884 non-null   float64
#  15  C_GEO       3884 non-null   object
#  16  Geo Point   3884 non-null   object
#  17  Geo Shape   3884 non-null   object
# dtypes: float64(4), int64(4), object(10)
# ...

# %%
df.head(5)
# Out:
#    CODE_UIC       LIBELLE FRET VOYAGEURS  CODE_LIGNE  RG_TRONCON       PK  \
# 0  87281451     Renescure    N         O      295000           1  058+389
# 1  87193250        Béning    O         O      172000           1  038+913
# 2  87481226   Ste-Pazanne    N         O      536000           1  000+475
# 3  87141218         Bayon    N         O       42000           1  014+994
# 4  87756007  Nice-St-Roch    O         N      945000           1  002+343
#
#                   COMMUNE          DEPARTEMEN  IDRESEAU  \
# 0               RENESCURE                NORD      6233
# 1  BENING-LES-SAINT-AVOLD             MOSELLE      3183
# 2          SAINTE-PAZANNE    LOIRE-ATLANTIQUE      8949
# 3               VIRECOURT  MEURTHE-ET-MOSELLE      3115
# 4                    NICE     ALPES-MARITIMES      5785
#
#                                  IDGAIA         X_L93         Y_L93   X_WGS84  \
# 0  d9d19624-6667-11e3-89ff-01f464e0362d  6.556053e+05  7.070764e+06  2.372331
# ...

# %%
#On garde uniquememnt les colonnes LIBELLE	VOYAGEURS	COMMUNE	DEPARTEMEN	X_WGS84	Y_WGS84
df=df.drop(columns={"CODE_UIC","FRET","CODE_LIGNE","RG_TRONCON","PK","IDRESEAU","IDGAIA"	,"X_L93"	,"Y_L93","C_GEO"	,"Geo Point",	"Geo Shape"})

# %%
df.head()
# Out:
#         LIBELLE VOYAGEURS                 COMMUNE          DEPARTEMEN  \
# 0     Renescure         O               RENESCURE                NORD
# 1        Béning         O  BENING-LES-SAINT-AVOLD             MOSELLE
# 2   Ste-Pazanne         O          SAINTE-PAZANNE    LOIRE-ATLANTIQUE
# 3         Bayon         O               VIRECOURT  MEURTHE-ET-MOSELLE
# 4  Nice-St-Roch         N                    NICE     ALPES-MARITIMES
#
#     X_WGS84    Y_WGS84
# 0  2.372331  50.731969
# 1  6.828570  49.138234
# 2 -1.817875  47.102437
# 3  6.322869  48.468006
# 4  7.286559  43.715174

# %%
print(df["X_WGS84"].isnull().sum())
print(df["Y_WGS84"].isnull().sum())
# Out:
# 0
# 0

# %%
df = df.dropna(subset=["X_WGS84", "Y_WGS84"])
print(df["X_WGS84"].isnull().sum())
print(df["Y_WGS84"].isnull().sum())
# Out:
# 0
# 0

# %%
df = df.rename(columns={"VOYAGEURS": "GARE_PASSAGER"})

# %%
df = df[df["GARE_PASSAGER"] == "O"]

# %%
df.head()
# Out:
#           LIBELLE GARE_PASSAGER                 COMMUNE          DEPARTEMEN  \
# 0       Renescure             O               RENESCURE                NORD
# 1          Béning             O  BENING-LES-SAINT-AVOLD             MOSELLE
# 2     Ste-Pazanne             O          SAINTE-PAZANNE    LOIRE-ATLANTIQUE
# 3           Bayon             O               VIRECOURT  MEURTHE-ET-MOSELLE
# 5  Soulac-sur-Mer             O          SOULAC-SUR-MER             GIRONDE
#
#     X_WGS84    Y_WGS84
# 0  2.372331  50.731969
# 1  6.828570  49.138234
# 2 -1.817875  47.102437
# 3  6.322869  48.468006
# 5 -1.117391  45.507970

# %%
df_numbers=df[["X_WGS84","Y_WGS84"]]

# %%
df_numbers.head()
# Out:
#     X_WGS84    Y_WGS84
# 0  2.372331  50.731969
# 1  6.828570  49.138234
# 2 -1.817875  47.102437
# 3  6.322869  48.468006
# 5 -1.117391  45.507970

# %%
import sklearn
from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=5)

# %%
kmeans.fit(df_numbers)
# Out:
# KMeans(n_clusters=5)

# %%
df_numbers.head()
# Out:
#     X_WGS84    Y_WGS84
# 0  2.372331  50.731969
# 1  6.828570  49.138234
# 2 -1.817875  47.102437
# 3  6.322869  48.468006
# 5 -1.117391  45.507970

# %%
df["cluster"]=kmeans.labels_

# %%
df.head()
# Out:
# LIBELLE             Foëcy
# GARE_PASSAGER           O
# COMMUNE             FOECY
# DEPARTEMEN           CHER
# X_WGS84          2.162645
# Name: 3883, dtype: object

# %%
#folium

import folium

# %%
folium.Map(location=[46.5, 2.5], zoom_start=6)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
# Pour une seule ligne (exemple)

for index, row in df.iterrows():
    folium.CircleMarker(location=[row["Y_WGS84"], row["X_WGS84"]])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_40096\2306824493.py in ?()
#       1 # Pour une seule ligne (exemple)
#       2
# ----> 3 for index, row in df.iterrows():
#       4     folium.CircleMarker(location=[row["Y_WGS84"], row["X_WGS84"]])
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'iterrows'

# %%
df.head(5)
# Out:
# LIBELLE             Foëcy
# GARE_PASSAGER           O
# COMMUNE             FOECY
# DEPARTEMEN           CHER
# X_WGS84          2.162645
# Name: 3883, dtype: object
